# %%
import pandas as pd

# %%
all_politics = pd.read_csv("../datasets/dataverse_files/1976-2020-president.csv")
all_politics = all_politics[all_politics['year']==2020]
all_politics.head()
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 3740  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3741  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3742  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3743  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3744  2020   ALASKA       AK           2         94        81  US PRESIDENT
#
#                 candidate party_detailed writein  candidatevotes  totalvotes  \
# 3740  BIDEN, JOSEPH R. JR       DEMOCRAT   False          849624     2323282
# 3741     TRUMP, DONALD J.     REPUBLICAN   False         1441170     2323282
# 3742        JORGENSEN, JO    LIBERTARIAN   False           25176     2323282
# 3743                  NaN            NaN    True            7312     2323282
# 3744  BIDEN, JOSEPH R. JR       DEMOCRAT   False          153778      359530
#
#        version  notes party_simplified
# ...

# %%
max_vote=all_politics.groupby(by=['state'])['candidatevotes'].idxmax()
all_politics.loc[max_vote][['state', 'state_po', 'party_simplified']]
# Out:
#                      state state_po party_simplified
# 3741               ALABAMA       AL       REPUBLICAN
# 3745                ALASKA       AK       REPUBLICAN
# 3752               ARIZONA       AZ         DEMOCRAT
# 3771              ARKANSAS       AR       REPUBLICAN
# 3773            CALIFORNIA       CA         DEMOCRAT
# 3784              COLORADO       CO         DEMOCRAT
# 3807           CONNECTICUT       CT         DEMOCRAT
# 3838              DELAWARE       DE         DEMOCRAT
# 3842  DISTRICT OF COLUMBIA       DC         DEMOCRAT
# 3850               FLORIDA       FL       REPUBLICAN
# 3878               GEORGIA       GA         DEMOCRAT
# 3881                HAWAII       HI         DEMOCRAT
# 3890                 IDAHO       ID       REPUBLICAN
# 3904              ILLINOIS       IL         DEMOCRAT
# 3925               INDIANA       IN       REPUBLICAN
# 3938                  IOWA       IA       REPUBLICAN
# 3950                KANSAS       KS       REPUBLICAN
# ...
